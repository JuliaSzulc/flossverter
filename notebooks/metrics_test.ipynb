# %%
import matplotlib.pyplot as plt
import pandas as pd
from metrics import (
    cie76,
    cie94,
    ciede2000,
    cmc_1_1,
    cmc_2_1,
    rgb_euclidean,
    rgb_euclidean_gamma_correction,
    xyz_euclidean,
)

from swatch import swatch

# %%
def display_colored(df):
    display(df.style.applymap(lambda c:"background-color: {}".format(c), subset=['rgb']))

# %% [markdown]
# # Color differences

# %%
dmc = pd.read_csv('../data/dmc.csv', index_col='number')
ariadna = pd.read_csv('../data/ariadna.csv', index_col='number')

# %%
base_numbers = ['4', '321', '518', '553', '701', '776', '921', '973', '3863', 'BLANC']

# %%
display_colored(dmc.loc[base_numbers])
# Out:
# <style type="text/css">
# #T_595c2_row0_col1 {
#   background-color: #757174;
# }
# #T_595c2_row1_col1 {
#   background-color: #c72b3b;
# }
# #T_595c2_row2_col1 {
#   background-color: #4f93a7;
# }
# #T_595c2_row3_col1 {
#   background-color: #a3638b;
# }
# #T_595c2_row4_col1 {
#   background-color: #3f8f29;
# }
# #T_595c2_row5_col1 {
#   background-color: #fcb0b9;
# }
# #T_595c2_row6_col1 {
#   background-color: #c66218;
# }
# #T_595c2_row7_col1 {
#   background-color: #ffe300;
# }
# #T_595c2_row8_col1 {
#   background-color: #a4835c;
# }
# #T_595c2_row9_col1 {
#   background-color: #fcfbf8;
# }
# </style>
# <table id="T_595c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_595c2_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_595c2_level0_col1" class="col_heading level0 col1" >rgb</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >number</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_595c2_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_595c2_row0_col0" class="data row0 col0" >Dark Tin</td>
#       <td id="T_595c2_row0_col1" class="data row0 col1" >#757174</td>
#     </tr>
#     <tr>
#       <th id="T_595c2_level0_row1" class="row_heading level0 row1" >321</th>
#       <td id="T_595c2_row1_col0" class="data row1 col0" >Red</td>
#       <td id="T_595c2_row1_col1" class="data row1 col1" >#c72b3b</td>
#     </tr>
#     <tr>
#       <th id="T_595c2_level0_row2" class="row_heading level0 row2" >518</th>
#       <td id="T_595c2_row2_col0" class="data row2 col0" >Light Wedgwood</td>
#       <td id="T_595c2_row2_col1" class="data row2 col1" >#4f93a7</td>
#     </tr>
#     <tr>
#       <th id="T_595c2_level0_row3" class="row_heading level0 row3" >553</th>
#       <td id="T_595c2_row3_col0" class="data row3 col0" >Violet</td>
#       <td id="T_595c2_row3_col1" class="data row3 col1" >#a3638b</td>
#     </tr>
#     <tr>
#       <th id="T_595c2_level0_row4" class="row_heading level0 row4" >701</th>
#       <td id="T_595c2_row4_col0" class="data row4 col0" >Light Green</td>
#       <td id="T_595c2_row4_col1" class="data row4 col1" >#3f8f29</td>
#     </tr>
#     <tr>
#       <th id="T_595c2_level0_row5" class="row_heading level0 row5" >776</th>
#       <td id="T_595c2_row5_col0" class="data row5 col0" >Medium Pink</td>
#       <td id="T_595c2_row5_col1" class="data row5 col1" >#fcb0b9</td>
#     </tr>
#     <tr>
#       <th id="T_595c2_level0_row6" class="row_heading level0 row6" >921</th>
#       <td id="T_595c2_row6_col0" class="data row6 col0" >Copper</td>
#       <td id="T_595c2_row6_col1" class="data row6 col1" >#c66218</td>
#     </tr>
#     <tr>
#       <th id="T_595c2_level0_row7" class="row_heading level0 row7" >973</th>
#       <td id="T_595c2_row7_col0" class="data row7 col0" >Bright Canary</td>
#       <td id="T_595c2_row7_col1" class="data row7 col1" >#ffe300</td>
#     </tr>
#     <tr>
#       <th id="T_595c2_level0_row8" class="row_heading level0 row8" >3863</th>
#       <td id="T_595c2_row8_col0" class="data row8 col0" >Medium Mocha Beige</td>
#       <td id="T_595c2_row8_col1" class="data row8 col1" >#a4835c</td>
#     </tr>
#     <tr>
#       <th id="T_595c2_level0_row9" class="row_heading level0 row9" >BLANC</th>
#       <td id="T_595c2_row9_col0" class="data row9 col0" >White</td>
#       <td id="T_595c2_row9_col1" class="data row9 col1" >#fcfbf8</td>
#     </tr>
#   </tbody>
# </table>

# %%
def find_similar(base_number, metric, ax=None, n=5, disp_tables=False):
    base_color = dmc.loc[base_number]['rgb']
    
    ariadna['distance'] = [metric(base_color, color) for color in ariadna['rgb']]
    similar_rows = ariadna.nsmallest(n, 'distance')
    
    if disp_tables:
        display_colored(similar_rows)
        
    swatch(base_color,
           similar_rows['rgb'].to_list(),
           ax,
           base_label=base_number,
           compared_labels=similar_rows.index.to_list(),
           vertical=True)

# %%
def run(metric, disp_tables=False):
    figsize = 30
    fig, axs = plt.subplots(1, len(base_numbers), figsize=(figsize, figsize))
    
    for ax, base_num in zip(axs.flat, base_numbers):
        find_similar(base_num, metric, ax, 5, disp_tables)

# %% [markdown]
# ## RGB space

# %% [markdown]
# ### RGB euclidean

# %% [markdown]
# $\text{score}=\text{distance} ^{2}={(R_{2}-R_{1})^{2}+(G_{2}-G_{1})^{2}+(B_{2}-B_{1})^{2}}$

# %%
run(rgb_euclidean)

# %% [markdown]
# ### RGB with gamma correction

# %% [markdown]
# ${\begin{cases}{\sqrt {2\times \Delta R^{2}+4\times \Delta G^{2}+3\times \Delta B^{2}}}&{\bar {R}}<128,\\{\sqrt {3\times \Delta R^{2}+4\times \Delta G^{2}+2\times \Delta B^{2}}}&\text{otherwise}\end{cases}}$
#
# ${\begin{aligned}\Delta R&=R_{1}-R_{2}\\\Delta G&=G_{1}-G_{2}\\\Delta B&=B_{1}-B_{2}\\{\bar {R}}&={{R_{1}+R_{2}} \over 2}\\\end{aligned}}$

# %%
run(rgb_euclidean_gamma_correction)

# %% [markdown]
# ## XYZ

# %% [markdown]
# $\text{score}=\text{distance} ^{2}={(X_{2}-X_{1})^{2}+(Y_{2}-Y_{1})^{2}+(Z_{2}-Z_{1})^{2}}$

# %%
run(xyz_euclidean)

# %% [markdown]
# ## CIELAB

# %% [markdown]
#  $\Delta E$ - (Delta E, dE) the measure of change in visual perception of two given colors

# %% [markdown]
# ### CIE76

# %% [markdown]
# $\Delta E={\sqrt {(L_{2}-L_{1})^{2}+(a_{2}-a_{1})^{2}+(b_{2}-b_{1})^{2}}}$

# %%
run(cie76)

# %% [markdown]
# ### CIE94

# %% [markdown]
# $\Delta E={\sqrt {\left({\frac {\Delta L}{k_{L}S_{L}}}\right)^{2}+\left({\frac {\Delta C}{k_{C}S_{C}}}\right)^{2}+\left({\frac {\Delta H}{k_{H}S_{H}}}\right)^{2}}}$
#
# $\begin{aligned}\Delta L&=L_{1}-L_{2}\\\Delta C&=C_{1}-C_{2} \quad C={\sqrt {{a}^{2}+{b}^{2}}}\\\Delta H&={\sqrt {{\Delta a}^{2}+{\Delta b}^{2}-{\Delta C}^{2}}}\\\end{aligned}$
#
# ${\begin{aligned}S_{L}&=1\\S_{C}&=1+K_{1}C_{1}\\S_{H}&=1+K_{2}C_{1}\\\end{aligned}}$
#
# ${k_{L}=k_{C}=k_{H}=1}$
#
# ${\begin{aligned}K_{1}&=0.045\\K_{2}&=0.015\\\end{aligned}}$

# %%
run(cie94)

# %% [markdown]
# ### CIEDE2000

# %% [markdown]
# $\Delta E={\sqrt {\left({\frac {\Delta L'}{k_{L}S_{L}}}\right)^{2}+\left({\frac {\Delta C'}{k_{C}S_{C}}}\right)^{2}+\left({\frac {\Delta H'}{k_{H}S_{H}}}\right)^{2}+R_{T}{\frac {\Delta C'}{k_{C}S_{C}}}{\frac {\Delta H'}{k_{H}S_{H}}}}}$
# ___
# ${\displaystyle {\bar {L}}={\frac {L_{1}+L_{2}}{2}}}$
#
# ${\displaystyle \Delta L^{\prime }=L_{2}-L_{1}}$
# ___
# ${\displaystyle {\bar {C}}={\frac {C_{1}+C_{2}}{2}} \quad {\bar {C^\prime}}={\frac {C_{1}^\prime+C_{2}^\prime}{2}}}$
#
# ${\displaystyle \Delta C^{\prime }=C_{2}^\prime-C_{1}^\prime}$
#
# $\begin{aligned}
# C^{\prime}&=\sqrt {a^{\prime2}+b^2}\\
# a^{\prime}&=a+\frac{a}{2}\left(1-\sqrt{\frac{\bar{C}^7}{\bar{C}^7+25^7}}\right)
# \end{aligned}$
# ___
#
# ${\begin{aligned}h^\prime&={\begin{cases}{\arctan(b/a^\prime)}&{\text{if }}\arctan(b/a^\prime) \geq 0\\{\arctan(b/a^\prime) + 360^{\circ}}&{\text{otherwise}}\end{cases}}\end{aligned}}$
#
# ${\displaystyle \Delta h'={\begin{cases}h_{2}^{\prime }-h_{1}^{\prime }&\left|h_{1}^{\prime }-h_{2}^{\prime }\right|\leq 180^{\circ }\\h_{2}^{\prime }-h_{1}^{\prime }+360^{\circ }&\left|h_{1}^{\prime }-h_{2}^{\prime }\right|>180^{\circ },h_{2}^{\prime }\leq h_{1}^{\prime }\\h_{2}^{\prime }-h_{1}^{\prime }-360^{\circ }&\left|h_{1}^{\prime }-h_{2}^{\prime }\right|>180^{\circ },h_{2}^{\prime }>h_{1}^{\prime }\end{cases}}}$
#
# ${\displaystyle \Delta H^{\prime }=2{\sqrt {C_{1}^{\prime }C_{2}^{\prime }}}\sin(\frac{\Delta h^{\prime }}{2}),\quad {\bar {H}}^{\prime }={\begin{cases}(h_{1}^{\prime }+h_{2}^{\prime })/2&\left|h_{1}^{\prime }-h_{2}^{\prime }\right|\leq 180^{\circ }\\(h_{1}^{\prime }+h_{2}^{\prime }+360^{\circ })/2&\left|h_{1}^{\prime }-h_{2}^{\prime }\right|>180^{\circ },h_{1}^{\prime }+h_{2}^{\prime }<360^{\circ }\\(h_{1}^{\prime }+h_{2}^{\prime }-360^{\circ })/2&\left|h_{1}^{\prime }-h_{2}^{\prime }\right|>180^{\circ },h_{1}^{\prime }+h_{2}^{\prime }\geq 360^{\circ }\end{cases}}}$
# ___
# ${\displaystyle T=1-0.17\cos({\bar {H}}^{\prime }-30)+0.24\cos(2{\bar {H}}^{\prime })+0.32\cos(3{\bar {H}}^{\prime }+6)-0.20\cos(4{\bar {H}}^{\prime }-63)}$
#
# ${\displaystyle \begin{aligned}S_{L}&=1+{\frac {0.015\left({\bar {L}}-50\right)^{2}}{\sqrt {20+{\left({\bar {L}}-50\right)}^{2}}}}\\S_{C}&=1+0.045{\bar {C}}^{\prime }\\S_{H}&=1+0.015{\bar {C}}^{\prime }T\\\end{aligned}}$
#
# ${\displaystyle R_{T}=-2{\sqrt {\frac {{\bar {C}}'^{7}}{{\bar {C}}'^{7}+25^{7}}}}\sin \left[60\cdot \exp \left(-\left[{\frac {{\bar {H}}'-275}{25}}\right]^{2}\right)\right]}$
#
# ${k_{L}=k_{C}=k_{H}=1}$

# %%
run(ciede2000)

# %% [markdown]
# ### CMC l:c

# %% [markdown]
# imperceptibility: $l:c \rightarrow 1:1$
# acceptability: $l:c \rightarrow 2:1$
#
# $\Delta E_{CMC}={\sqrt {\left({\frac {L_{2}-L_{1}}{l\times S_{L}}}\right)^{2}+\left({\frac {C_{2}-C_{1}}{c\times S_{C}}}\right)^{2}+\left({\frac {\Delta H}{S_{H}}}\right)^{2}}}$
#
# $S_{L}={\begin{cases}0.511&L_{1}<16\\{\frac {0.040975L_{1}}{1+0.01765L_{1}}}&L_{1}\geq 16\end{cases}}\quad S_{C}={\frac {0.0638C_{1}}{1+0.0131C_{1}}}+0.638\quad S_{H}=S_{C}(FT+1-F)$
#
# $F={\sqrt {\frac {C_{1}^4}{C_{1}^4+1900}}}\quad T={\begin{cases}0.56+|0.2\cos(h_{1}+168^{\circ })|&164^{\circ }\leq h_{1}\leq 345^{\circ }\\0.36+|0.4\cos(h_{1}+35^{\circ})|&{\text{otherwise}}\end{cases}}$

# %%
run(cmc_1_1)

# %%
run(cmc_2_1)
